# %%
using DelimitedFiles

# %%
open("mostunstable.dat", "w") do io
    for R = 85 : 5 : 500
        data = readdlm("R=$R.dat",skipstart=3)
        for i = 2 : size(data,1)
            if data[i,5]> data[i-1,5] && data[i,5] > data[i+1,5] && data[i,5] > 0
                mostunstable = data[i,:]
                writedlm(io, [mostunstable])
            end
        end
    end
end

# %%
writedlm("R=280.dat",data)

# %%
open("Stability_Zarf_Ts=0.0.dat", "w") do io
    for R = 85 : 5 : 500
        data = readdlm("R=$R.dat",skipstart=3)
        # data[:,4] .+= data[:,3]
        writedlm(io, data)
    end
end
