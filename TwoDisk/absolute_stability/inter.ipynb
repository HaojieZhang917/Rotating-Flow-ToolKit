# %%
using BSplineKit
using DelimitedFiles
using Plots
using Loess
using Interpolations
# Out:
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up

# %%
data = readdlm("AS_0.0.dat")
# Out:
# 73×6 Matrix{Float64}:
#  812.0  0.2565  0.262288  -0.118687  -0.0585026    1.51722e-5
#  796.0  0.254   0.262774  -0.119502  -0.0578643   -2.12327e-6
#  782.0  0.2515  0.263193  -0.120227  -0.0572074   -9.83994e-6
#  770.0  0.249   0.263545  -0.120863  -0.0565317   -6.52839e-6
#  758.0  0.2465  0.263871  -0.121504  -0.0558532   -8.19721e-6
#  746.0  0.244   0.264171  -0.12215   -0.0551718   -1.49654e-5
#  736.0  0.2415  0.264403  -0.12271   -0.0544715   -8.57858e-6
#  726.0  0.239   0.264609  -0.123277  -0.0537684   -6.53475e-6
#  716.0  0.2365  0.26479   -0.123849  -0.0530624   -8.91788e-6
#  706.0  0.234   0.264945  -0.124427  -0.0523535   -1.58148e-5
#    ⋮                                               ⋮
#  674.0  0.0965  0.219486  -0.163813  -0.00753613   1.42071e-5
#  686.0  0.094   0.217646  -0.165332  -0.00670081   1.21751e-6
#  702.0  0.0915  0.21574   -0.166852  -0.00587272   9.75189e-6
#  718.0  0.089   0.213826  -0.168457  -0.00504673   3.80762e-6
# ...

# %%
model = loess(data[:,2], data[:,1], span = 0.2, degree = 2)
# Out:
# Loess.LoessModel{Float64}([0.25650000000000156; 0.25400000000000156; … ; 0.0790000000000014; 0.0765000000000014;;], [812.0, 796.0, 782.0, 770.0, 758.0, 746.0, 736.0, 726.0, 716.0, 706.0  …  662.0, 674.0, 686.0, 702.0, 718.0, 738.0, 758.0, 782.0, 808.0, 838.0], Dict([0.23900000000000154] => [725.5618869064259, 4004.2578420672307], [0.21900000000000153] => [658.8911050283023, 2795.7421579327556], [0.13400000000000145] => [579.6660200769539, -874.5029713508634], [0.20650000000000152] => [628.6488081674516, 2167.7003678208234], [0.21150000000000152] => [639.6941921712806, 2371.4626908481123], [0.17150000000000148] => [577.6555025125859, 812.149416520369], [0.09400000000000142] => [686.765109937702, -5879.668943726638], [0.15650000000000147] => [570.6539936882568, 104.59834476990144], [0.13900000000000146] => [575.6885036399264, -691.1438131628535], [0.22900000000000154] => [689.6636986842549, 3337.3934959890207]…), Dict([0.23900000000000154] => [0.0 -0.015246743512836808 … 0.0 0.0; 0.0 2
# ...

# %%
x_fine = range(0.077,0.255, length = 400)
y_smooth = predict(model,x_fine)
writedlm("test.dat", [y_smooth x_fine])

# %%
plot(x_fine, y_smooth,xlims=[-0.4,0.4],ylims=[0,700])

# %%
plot!(data[:,2], data[:,1],xlims=[-0.4,0.4],ylims=[0,700])
